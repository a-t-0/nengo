# %% [markdown]
# # NEF summary
#
# The Neural Engineering Framework (NEF)
# is one set of theoretical methods that are used in
# Nengo for constructing neural models.
# The NEF is based on [Eliasmith & Anderson's (2003) book](
# https://mitpress.mit.edu/books/neural-engineering) from MIT Press.
# This notebook introduces the three main principles
# discussed in that book and implemented in Nengo.

# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt

import nengo
from nengo.dists import Uniform
from nengo.processes import WhiteSignal
from nengo.utils.ensemble import tuning_curves
from nengo.utils.ipython import hide_input
from nengo.utils.matplotlib import rasterplot


def aligned(n_neurons, radius=0.9):
    intercepts = np.linspace(-radius, radius, n_neurons)
    encoders = np.tile([[1], [-1]], (n_neurons // 2, 1))
    intercepts *= encoders[:, 0]
    return intercepts, encoders


hide_input()
# Out:
#         <a id="2027955447" href="javascript:toggle_input_2027955447()"
#           >Show Input</a>
#
#         <script type="text/javascript">
#         var toggle_input_2027955447;
#         (function() {
#             if (typeof jQuery == 'undefined') {
#                 // no jQuery
#                 var link_2027955447 = document.getElementById("2027955447");
#                 var cell = link_2027955447;
#                 while (cell.className.split(' ')[0] != "cell"
#                        && cell.className.split(' ')[0] != "nboutput") {
#                     cell = cell.parentNode;
#                 }
#                 var input_2027955447;
#                 if (cell.className.split(' ')[0] == "cell") {
#                     for (var i = 0; i < cell.children.length; i++) {
#                         if (cell.children[i].className.split(' ')[0]
#                             == "input") {
#                             input_2027955447 = cell.children[i];
#                         }
#                     }
#                 } else {
#                     input_2027955447 = cell.previousElementSibling;
#                 }
#                 input_2027955447.style.display = "none"; // hide
#
#                 toggle_input_2027955447 = function() {
#                     if (input_2027955447.style.display == "none") {
#                         input_2027955447.style.display = ""; // show
#                         link_2027955447.innerHTML = "Hide Input";
#                     } else {
#                         input_2027955447.style.display = "none"; // hide
#                         link_2027955447.innerHTML = "Show Input";
#                     }
#                 }
#
#             } else {
#                 // jQuery
#                 var link_2027955447 = $("a[id='2027955447']");
#                 var cell_2027955447 = link_2027955447.parents("div.cell:first");
#                 if (cell_2027955447.length == 0) {
#                     cell_2027955447 = link_2027955447.parents(
#                         "div.nboutput:first");
#                 }
#                 var input_2027955447 = cell_2027955447.children("div.input");
#                 if (input_2027955447.length == 0) {
#                     input_2027955447 = cell_2027955447.prev("div.nbinput");
#                 }
#                 input_2027955447.hide();
#
#                 toggle_input_2027955447 = function() {
#                     if (input_2027955447.is(':hidden')) {
#                         input_2027955447.slideDown();
#                         link_2027955447[0].innerHTML = "Hide Input";
#                     } else {
#                         input_2027955447.slideUp();
#                         link_2027955447[0].innerHTML = "Show Input";
#                     }
#                 }
#             }
#         }());
#         </script>

# %% [markdown]
# ## Principle 1: Representation
#
# ### Encoding
#
# Neural populations represent time-varying signals
# through their spiking responses.
# A signal is a vector of real numbers of arbitrary length.
# This example is a 1D signal going from -1 to 1 in 1 second.

# %%
model = nengo.Network(label="NEF summary")
with model:
    input = nengo.Node(lambda t: t * 2 - 1)
    input_probe = nengo.Probe(input)

# %%
with nengo.Simulator(model) as sim:
    sim.run(1.0)

plt.figure()
plt.plot(sim.trange(), sim.data[input_probe], lw=2)
plt.title("Input signal")
plt.xlabel("Time (s)")
plt.xlim(0, 1)
hide_input()
# Out:
#         <a id="662762974" href="javascript:toggle_input_662762974()"
#           >Show Input</a>
#
#         <script type="text/javascript">
#         var toggle_input_662762974;
#         (function() {
#             if (typeof jQuery == 'undefined') {
#                 // no jQuery
#                 var link_662762974 = document.getElementById("662762974");
#                 var cell = link_662762974;
#                 while (cell.className.split(' ')[0] != "cell"
#                        && cell.className.split(' ')[0] != "nboutput") {
#                     cell = cell.parentNode;
#                 }
#                 var input_662762974;
#                 if (cell.className.split(' ')[0] == "cell") {
#                     for (var i = 0; i < cell.children.length; i++) {
#                         if (cell.children[i].className.split(' ')[0]
#                             == "input") {
#                             input_662762974 = cell.children[i];
#                         }
#                     }
#                 } else {
#                     input_662762974 = cell.previousElementSibling;
#                 }
#                 input_662762974.style.display = "none"; // hide
#
#                 toggle_input_662762974 = function() {
#                     if (input_662762974.style.display == "none") {
#                         input_662762974.style.display = ""; // show
#                         link_662762974.innerHTML = "Hide Input";
#                     } else {
#                         input_662762974.style.display = "none"; // hide
#                         link_662762974.innerHTML = "Show Input";
#                     }
#                 }
#
#             } else {
#                 // jQuery
#                 var link_662762974 = $("a[id='662762974']");
#                 var cell_662762974 = link_662762974.parents("div.cell:first");
#                 if (cell_662762974.length == 0) {
#                     cell_662762974 = link_662762974.parents(
#                         "div.nboutput:first");
#                 }
#                 var input_662762974 = cell_662762974.children("div.input");
#                 if (input_662762974.length == 0) {
#                     input_662762974 = cell_662762974.prev("div.nbinput");
#                 }
#                 input_662762974.hide();
#
#                 toggle_input_662762974 = function() {
#                     if (input_662762974.is(':hidden')) {
#                         input_662762974.slideDown();
#                         link_662762974[0].innerHTML = "Hide Input";
#                     } else {
#                         input_662762974.slideUp();
#                         link_662762974[0].innerHTML = "Show Input";
#                     }
#                 }
#             }
#         }());
#         </script>

# %% [markdown]
# These signals drive neural populations
# based on each neuron's *tuning curve*
# (which is similar to the current-frequency curve,
# if you're familiar with that).
#
# The tuning curve describes how much
# a particular neuron will fire as a function of the input signal.

# %%
intercepts, encoders = aligned(8)  # Makes evenly spaced intercepts
with model:
    A = nengo.Ensemble(
        8,
        dimensions=1,
        intercepts=intercepts,
        max_rates=Uniform(80, 100),
        encoders=encoders,
    )

# %%
with nengo.Simulator(model) as sim:
    eval_points, activities = tuning_curves(A, sim)

plt.figure()
plt.plot(eval_points, activities, lw=2)
plt.xlabel("Input signal")
plt.ylabel("Firing rate (Hz)")
hide_input()
# Out:
#         <a id="844572341" href="javascript:toggle_input_844572341()"
#           >Show Input</a>
#
#         <script type="text/javascript">
#         var toggle_input_844572341;
#         (function() {
#             if (typeof jQuery == 'undefined') {
#                 // no jQuery
#                 var link_844572341 = document.getElementById("844572341");
#                 var cell = link_844572341;
#                 while (cell.className.split(' ')[0] != "cell"
#                        && cell.className.split(' ')[0] != "nboutput") {
#                     cell = cell.parentNode;
#                 }
#                 var input_844572341;
#                 if (cell.className.split(' ')[0] == "cell") {
#                     for (var i = 0; i < cell.children.length; i++) {
#                         if (cell.children[i].className.split(' ')[0]
#                             == "input") {
#                             input_844572341 = cell.children[i];
#                         }
#                     }
#                 } else {
#                     input_844572341 = cell.previousElementSibling;
#                 }
#                 input_844572341.style.display = "none"; // hide
#
#                 toggle_input_844572341 = function() {
#                     if (input_844572341.style.display == "none") {
#                         input_844572341.style.display = ""; // show
#                         link_844572341.innerHTML = "Hide Input";
#                     } else {
#                         input_844572341.style.display = "none"; // hide
#                         link_844572341.innerHTML = "Show Input";
#                     }
#                 }
#
#             } else {
#                 // jQuery
#                 var link_844572341 = $("a[id='844572341']");
#                 var cell_844572341 = link_844572341.parents("div.cell:first");
#                 if (cell_844572341.length == 0) {
#                     cell_844572341 = link_844572341.parents(
#                         "div.nboutput:first");
#                 }
#                 var input_844572341 = cell_844572341.children("div.input");
#                 if (input_844572341.length == 0) {
#                     input_844572341 = cell_844572341.prev("div.nbinput");
#                 }
#                 input_844572341.hide();
#
#                 toggle_input_844572341 = function() {
#                     if (input_844572341.is(':hidden')) {
#                         input_844572341.slideDown();
#                         link_844572341[0].innerHTML = "Hide Input";
#                     } else {
#                         input_844572341.slideUp();
#                         link_844572341[0].innerHTML = "Show Input";
#                     }
#                 }
#             }
#         }());
#         </script>

# %% [markdown]
# We can drive these neurons with our input signal
# and observe their spiking activity over time.

# %%
with model:
    nengo.Connection(input, A)
    A_spikes = nengo.Probe(A.neurons)

# %%
with nengo.Simulator(model) as sim:
    sim.run(1)

plt.figure()
ax = plt.subplot(1, 1, 1)
rasterplot(sim.trange(), sim.data[A_spikes], ax)
ax.set_xlim(0, 1)
ax.set_ylabel("Neuron")
ax.set_xlabel("Time (s)")
hide_input()
# Out:
#         <a id="2075756389" href="javascript:toggle_input_2075756389()"
#           >Show Input</a>
#
#         <script type="text/javascript">
#         var toggle_input_2075756389;
#         (function() {
#             if (typeof jQuery == 'undefined') {
#                 // no jQuery
#                 var link_2075756389 = document.getElementById("2075756389");
#                 var cell = link_2075756389;
#                 while (cell.className.split(' ')[0] != "cell"
#                        && cell.className.split(' ')[0] != "nboutput") {
#                     cell = cell.parentNode;
#                 }
#                 var input_2075756389;
#                 if (cell.className.split(' ')[0] == "cell") {
#                     for (var i = 0; i < cell.children.length; i++) {
#                         if (cell.children[i].className.split(' ')[0]
#                             == "input") {
#                             input_2075756389 = cell.children[i];
#                         }
#                     }
#                 } else {
#                     input_2075756389 = cell.previousElementSibling;
#                 }
#                 input_2075756389.style.display = "none"; // hide
#
#                 toggle_input_2075756389 = function() {
#                     if (input_2075756389.style.display == "none") {
#                         input_2075756389.style.display = ""; // show
#                         link_2075756389.innerHTML = "Hide Input";
#                     } else {
#                         input_2075756389.style.display = "none"; // hide
#                         link_2075756389.innerHTML = "Show Input";
#                     }
#                 }
#
#             } else {
#                 // jQuery
#                 var link_2075756389 = $("a[id='2075756389']");
#                 var cell_2075756389 = link_2075756389.parents("div.cell:first");
#                 if (cell_2075756389.length == 0) {
#                     cell_2075756389 = link_2075756389.parents(
#                         "div.nboutput:first");
#                 }
#                 var input_2075756389 = cell_2075756389.children("div.input");
#                 if (input_2075756389.length == 0) {
#                     input_2075756389 = cell_2075756389.prev("div.nbinput");
#                 }
#                 input_2075756389.hide();
#
#                 toggle_input_2075756389 = function() {
#                     if (input_2075756389.is(':hidden')) {
#                         input_2075756389.slideDown();
#                         link_2075756389[0].innerHTML = "Hide Input";
#                     } else {
#                         input_2075756389.slideUp();
#                         link_2075756389[0].innerHTML = "Show Input";
#                     }
#                 }
#             }
#         }());
#         </script>

# %% [markdown]
# ### Decoding
#
# We can estimate the input signal
# originally encoded by decoding the pattern of spikes.
# To do this, we first filter the spike train
# with a temporal filter that accounts for
# postsynaptic current (PSC) activity.

# %%
model = nengo.Network(label="NEF summary")
with model:
    input = nengo.Node(lambda t: t * 2 - 1)
    input_probe = nengo.Probe(input)
    intercepts, encoders = aligned(8)  # Makes evenly spaced intercepts
    A = nengo.Ensemble(
        8,
        dimensions=1,
        intercepts=intercepts,
        max_rates=Uniform(80, 100),
        encoders=encoders,
    )
    nengo.Connection(input, A)
    A_spikes = nengo.Probe(A.neurons, synapse=0.01)

# %%
with nengo.Simulator(model) as sim:
    sim.run(1)

scale = 180
plt.figure()
for i in range(A.n_neurons):
    plt.plot(sim.trange(), sim.data[A_spikes][:, i] - i * scale)
plt.xlim(0, 1)
plt.ylim(scale * (-A.n_neurons + 1), scale)
plt.ylabel("Neuron")
plt.yticks(
    np.arange(scale / 1.8, (-A.n_neurons + 1) * scale, -scale), np.arange(A.n_neurons)
)
hide_input()
# Out:
#         <a id="2089603498" href="javascript:toggle_input_2089603498()"
#           >Show Input</a>
#
#         <script type="text/javascript">
#         var toggle_input_2089603498;
#         (function() {
#             if (typeof jQuery == 'undefined') {
#                 // no jQuery
#                 var link_2089603498 = document.getElementById("2089603498");
#                 var cell = link_2089603498;
#                 while (cell.className.split(' ')[0] != "cell"
#                        && cell.className.split(' ')[0] != "nboutput") {
#                     cell = cell.parentNode;
#                 }
#                 var input_2089603498;
#                 if (cell.className.split(' ')[0] == "cell") {
#                     for (var i = 0; i < cell.children.length; i++) {
#                         if (cell.children[i].className.split(' ')[0]
#                             == "input") {
#                             input_2089603498 = cell.children[i];
#                         }
#                     }
#                 } else {
#                     input_2089603498 = cell.previousElementSibling;
#                 }
#                 input_2089603498.style.display = "none"; // hide
#
#                 toggle_input_2089603498 = function() {
#                     if (input_2089603498.style.display == "none") {
#                         input_2089603498.style.display = ""; // show
#                         link_2089603498.innerHTML = "Hide Input";
#                     } else {
#                         input_2089603498.style.display = "none"; // hide
#                         link_2089603498.innerHTML = "Show Input";
#                     }
#                 }
#
#             } else {
#                 // jQuery
#                 var link_2089603498 = $("a[id='2089603498']");
#                 var cell_2089603498 = link_2089603498.parents("div.cell:first");
#                 if (cell_2089603498.length == 0) {
#                     cell_2089603498 = link_2089603498.parents(
#                         "div.nboutput:first");
#                 }
#                 var input_2089603498 = cell_2089603498.children("div.input");
#                 if (input_2089603498.length == 0) {
#                     input_2089603498 = cell_2089603498.prev("div.nbinput");
#                 }
#                 input_2089603498.hide();
#
#                 toggle_input_2089603498 = function() {
#                     if (input_2089603498.is(':hidden')) {
#                         input_2089603498.slideDown();
#                         link_2089603498[0].innerHTML = "Hide Input";
#                     } else {
#                         input_2089603498.slideUp();
#                         link_2089603498[0].innerHTML = "Show Input";
#                     }
#                 }
#             }
#         }());
#         </script>

# %% [markdown]
# Then we mulitply those filtered spike trains
# with decoding weights and sum them together
# to give an estimate of the input based on the spikes.
#
# The decoding weights are determined
# by minimizing the squared difference
# between the decoded estimate and the actual input signal.

# %%
with model:
    A_probe = nengo.Probe(A, synapse=0.01)  # 10ms PSC filter

# %%
with nengo.Simulator(model) as sim:
    sim.run(1)

plt.figure()
plt.plot(sim.trange(), sim.data[input_probe], label="Input signal")
plt.plot(sim.trange(), sim.data[A_probe], label="Decoded estimate")
plt.legend(loc="best")
plt.xlim(0, 1)
hide_input()
# Out:
#         <a id="345984768" href="javascript:toggle_input_345984768()"
#           >Show Input</a>
#
#         <script type="text/javascript">
#         var toggle_input_345984768;
#         (function() {
#             if (typeof jQuery == 'undefined') {
#                 // no jQuery
#                 var link_345984768 = document.getElementById("345984768");
#                 var cell = link_345984768;
#                 while (cell.className.split(' ')[0] != "cell"
#                        && cell.className.split(' ')[0] != "nboutput") {
#                     cell = cell.parentNode;
#                 }
#                 var input_345984768;
#                 if (cell.className.split(' ')[0] == "cell") {
#                     for (var i = 0; i < cell.children.length; i++) {
#                         if (cell.children[i].className.split(' ')[0]
#                             == "input") {
#                             input_345984768 = cell.children[i];
#                         }
#                     }
#                 } else {
#                     input_345984768 = cell.previousElementSibling;
#                 }
#                 input_345984768.style.display = "none"; // hide
#
#                 toggle_input_345984768 = function() {
#                     if (input_345984768.style.display == "none") {
#                         input_345984768.style.display = ""; // show
#                         link_345984768.innerHTML = "Hide Input";
#                     } else {
#                         input_345984768.style.display = "none"; // hide
#                         link_345984768.innerHTML = "Show Input";
#                     }
#                 }
#
#             } else {
#                 // jQuery
#                 var link_345984768 = $("a[id='345984768']");
#                 var cell_345984768 = link_345984768.parents("div.cell:first");
#                 if (cell_345984768.length == 0) {
#                     cell_345984768 = link_345984768.parents(
#                         "div.nboutput:first");
#                 }
#                 var input_345984768 = cell_345984768.children("div.input");
#                 if (input_345984768.length == 0) {
#                     input_345984768 = cell_345984768.prev("div.nbinput");
#                 }
#                 input_345984768.hide();
#
#                 toggle_input_345984768 = function() {
#                     if (input_345984768.is(':hidden')) {
#                         input_345984768.slideDown();
#                         link_345984768[0].innerHTML = "Hide Input";
#                     } else {
#                         input_345984768.slideUp();
#                         link_345984768[0].innerHTML = "Show Input";
#                     }
#                 }
#             }
#         }());
#         </script>

# %% [markdown]
# The accuracy of the decoded estimate increases
# as the number of neurons increases.

# %%
model = nengo.Network(label="NEF summary")
with model:
    input = nengo.Node(lambda t: t * 2 - 1)
    input_probe = nengo.Probe(input)
    A = nengo.Ensemble(30, dimensions=1, max_rates=Uniform(80, 100))
    nengo.Connection(input, A)
    A_spikes = nengo.Probe(A.neurons)
    A_probe = nengo.Probe(A, synapse=0.01)

# %%
with nengo.Simulator(model) as sim:
    sim.run(1)

plt.figure(figsize=(15, 3.5))

plt.subplot(1, 3, 1)
eval_points, activities = tuning_curves(A, sim)
plt.plot(eval_points, activities, lw=2)
plt.xlabel("Input signal")
plt.ylabel("Firing rate (Hz)")

ax = plt.subplot(1, 3, 2)
rasterplot(sim.trange(), sim.data[A_spikes], ax)
plt.xlim(0, 1)
plt.xlabel("Time (s)")
plt.ylabel("Neuron")

plt.subplot(1, 3, 3)
plt.plot(sim.trange(), sim.data[input_probe], label="Input signal")
plt.plot(sim.trange(), sim.data[A_probe], label="Decoded esimate")
plt.legend(loc="best")
plt.xlabel("Time (s)")
plt.xlim(0, 1)
hide_input()
# Out:
#         <a id="1512893411" href="javascript:toggle_input_1512893411()"
#           >Show Input</a>
#
#         <script type="text/javascript">
#         var toggle_input_1512893411;
#         (function() {
#             if (typeof jQuery == 'undefined') {
#                 // no jQuery
#                 var link_1512893411 = document.getElementById("1512893411");
#                 var cell = link_1512893411;
#                 while (cell.className.split(' ')[0] != "cell"
#                        && cell.className.split(' ')[0] != "nboutput") {
#                     cell = cell.parentNode;
#                 }
#                 var input_1512893411;
#                 if (cell.className.split(' ')[0] == "cell") {
#                     for (var i = 0; i < cell.children.length; i++) {
#                         if (cell.children[i].className.split(' ')[0]
#                             == "input") {
#                             input_1512893411 = cell.children[i];
#                         }
#                     }
#                 } else {
#                     input_1512893411 = cell.previousElementSibling;
#                 }
#                 input_1512893411.style.display = "none"; // hide
#
#                 toggle_input_1512893411 = function() {
#                     if (input_1512893411.style.display == "none") {
#                         input_1512893411.style.display = ""; // show
#                         link_1512893411.innerHTML = "Hide Input";
#                     } else {
#                         input_1512893411.style.display = "none"; // hide
#                         link_1512893411.innerHTML = "Show Input";
#                     }
#                 }
#
#             } else {
#                 // jQuery
#                 var link_1512893411 = $("a[id='1512893411']");
#                 var cell_1512893411 = link_1512893411.parents("div.cell:first");
#                 if (cell_1512893411.length == 0) {
#                     cell_1512893411 = link_1512893411.parents(
#                         "div.nboutput:first");
#                 }
#                 var input_1512893411 = cell_1512893411.children("div.input");
#                 if (input_1512893411.length == 0) {
#                     input_1512893411 = cell_1512893411.prev("div.nbinput");
#                 }
#                 input_1512893411.hide();
#
#                 toggle_input_1512893411 = function() {
#                     if (input_1512893411.is(':hidden')) {
#                         input_1512893411.slideDown();
#                         link_1512893411[0].innerHTML = "Hide Input";
#                     } else {
#                         input_1512893411.slideUp();
#                         link_1512893411[0].innerHTML = "Show Input";
#                     }
#                 }
#             }
#         }());
#         </script>

# %% [markdown]
# Any smooth signal can be encoded and decoded.

# %%
model = nengo.Network(label="NEF summary")
with model:
    input = nengo.Node(WhiteSignal(1, high=5), size_out=1)
    input_probe = nengo.Probe(input)
    A = nengo.Ensemble(30, dimensions=1, max_rates=Uniform(80, 100))
    nengo.Connection(input, A)
    A_spikes = nengo.Probe(A.neurons)
    A_probe = nengo.Probe(A, synapse=0.01)

# %%
with nengo.Simulator(model) as sim:
    sim.run(1)

plt.figure(figsize=(10, 3.5))
plt.subplot(1, 2, 1)
plt.plot(sim.trange(), sim.data[input_probe], label="Input signal")
plt.plot(sim.trange(), sim.data[A_probe], label="Decoded esimate")
plt.legend(loc="best")
plt.xlabel("Time (s)")
plt.xlim(0, 1)

ax = plt.subplot(1, 2, 2)
rasterplot(sim.trange(), sim.data[A_spikes], ax)
plt.xlim(0, 1)
plt.xlabel("Time (s)")
plt.ylabel("Neuron")
hide_input()
# Out:
#         <a id="1158215102" href="javascript:toggle_input_1158215102()"
#           >Show Input</a>
#
#         <script type="text/javascript">
#         var toggle_input_1158215102;
#         (function() {
#             if (typeof jQuery == 'undefined') {
#                 // no jQuery
#                 var link_1158215102 = document.getElementById("1158215102");
#                 var cell = link_1158215102;
#                 while (cell.className.split(' ')[0] != "cell"
#                        && cell.className.split(' ')[0] != "nboutput") {
#                     cell = cell.parentNode;
#                 }
#                 var input_1158215102;
#                 if (cell.className.split(' ')[0] == "cell") {
#                     for (var i = 0; i < cell.children.length; i++) {
#                         if (cell.children[i].className.split(' ')[0]
#                             == "input") {
#                             input_1158215102 = cell.children[i];
#                         }
#                     }
#                 } else {
#                     input_1158215102 = cell.previousElementSibling;
#                 }
#                 input_1158215102.style.display = "none"; // hide
#
#                 toggle_input_1158215102 = function() {
#                     if (input_1158215102.style.display == "none") {
#                         input_1158215102.style.display = ""; // show
#                         link_1158215102.innerHTML = "Hide Input";
#                     } else {
#                         input_1158215102.style.display = "none"; // hide
#                         link_1158215102.innerHTML = "Show Input";
#                     }
#                 }
#
#             } else {
#                 // jQuery
#                 var link_1158215102 = $("a[id='1158215102']");
#                 var cell_1158215102 = link_1158215102.parents("div.cell:first");
#                 if (cell_1158215102.length == 0) {
#                     cell_1158215102 = link_1158215102.parents(
#                         "div.nboutput:first");
#                 }
#                 var input_1158215102 = cell_1158215102.children("div.input");
#                 if (input_1158215102.length == 0) {
#                     input_1158215102 = cell_1158215102.prev("div.nbinput");
#                 }
#                 input_1158215102.hide();
#
#                 toggle_input_1158215102 = function() {
#                     if (input_1158215102.is(':hidden')) {
#                         input_1158215102.slideDown();
#                         link_1158215102[0].innerHTML = "Hide Input";
#                     } else {
#                         input_1158215102.slideUp();
#                         link_1158215102[0].innerHTML = "Show Input";
#                     }
#                 }
#             }
#         }());
#         </script>

# %% [markdown]
# ## Principle 2: Transformation
#
# Encoding and decoding allow us to encode signals over time,
# and decode transformations of those signals.
#
# In fact, we can decode arbitrary transformations of the input signal,
# not just the signal itself (as in the previous example).
#
# Let's decode the square of our white noise input.

# %%
model = nengo.Network(label="NEF summary")
with model:
    input = nengo.Node(WhiteSignal(1, high=5), size_out=1)
    input_probe = nengo.Probe(input)
    A = nengo.Ensemble(30, dimensions=1, max_rates=Uniform(80, 100))
    Asquare = nengo.Node(size_in=1)
    nengo.Connection(input, A)
    nengo.Connection(A, Asquare, function=np.square)
    A_spikes = nengo.Probe(A.neurons)
    Asquare_probe = nengo.Probe(Asquare, synapse=0.01)

# %%
with nengo.Simulator(model) as sim:
    sim.run(1)

plt.figure(figsize=(10, 3.5))
plt.subplot(1, 2, 1)
plt.plot(sim.trange(), sim.data[input_probe], label="Input signal")
plt.plot(sim.trange(), sim.data[Asquare_probe], label="Decoded esimate")
plt.plot(sim.trange(), np.square(sim.data[input_probe]), label="Input signal squared")
plt.legend(loc="best", fontsize="medium")
plt.xlabel("Time (s)")
plt.xlim(0, 1)

ax = plt.subplot(1, 2, 2)
rasterplot(sim.trange(), sim.data[A_spikes])
plt.xlim(0, 1)
plt.xlabel("Time (s)")
plt.ylabel("Neuron")
hide_input()
# Out:
#         <a id="332348428" href="javascript:toggle_input_332348428()"
#           >Show Input</a>
#
#         <script type="text/javascript">
#         var toggle_input_332348428;
#         (function() {
#             if (typeof jQuery == 'undefined') {
#                 // no jQuery
#                 var link_332348428 = document.getElementById("332348428");
#                 var cell = link_332348428;
#                 while (cell.className.split(' ')[0] != "cell"
#                        && cell.className.split(' ')[0] != "nboutput") {
#                     cell = cell.parentNode;
#                 }
#                 var input_332348428;
#                 if (cell.className.split(' ')[0] == "cell") {
#                     for (var i = 0; i < cell.children.length; i++) {
#                         if (cell.children[i].className.split(' ')[0]
#                             == "input") {
#                             input_332348428 = cell.children[i];
#                         }
#                     }
#                 } else {
#                     input_332348428 = cell.previousElementSibling;
#                 }
#                 input_332348428.style.display = "none"; // hide
#
#                 toggle_input_332348428 = function() {
#                     if (input_332348428.style.display == "none") {
#                         input_332348428.style.display = ""; // show
#                         link_332348428.innerHTML = "Hide Input";
#                     } else {
#                         input_332348428.style.display = "none"; // hide
#                         link_332348428.innerHTML = "Show Input";
#                     }
#                 }
#
#             } else {
#                 // jQuery
#                 var link_332348428 = $("a[id='332348428']");
#                 var cell_332348428 = link_332348428.parents("div.cell:first");
#                 if (cell_332348428.length == 0) {
#                     cell_332348428 = link_332348428.parents(
#                         "div.nboutput:first");
#                 }
#                 var input_332348428 = cell_332348428.children("div.input");
#                 if (input_332348428.length == 0) {
#                     input_332348428 = cell_332348428.prev("div.nbinput");
#                 }
#                 input_332348428.hide();
#
#                 toggle_input_332348428 = function() {
#                     if (input_332348428.is(':hidden')) {
#                         input_332348428.slideDown();
#                         link_332348428[0].innerHTML = "Hide Input";
#                     } else {
#                         input_332348428.slideUp();
#                         link_332348428[0].innerHTML = "Show Input";
#                     }
#                 }
#             }
#         }());
#         </script>

# %% [markdown]
# Notice that the spike trains are exactly the same.
# The only difference is how we're interpreting those spikes.
# We told Nengo to compute a new set of decoders
# that estimate the function $x^2$.
#
# In general, the transformation principle
# determines how we can decode spike trains
# to compute linear and nonlinear transformations of signals
# encoded in a population of neurons.
# We can then project those transformed signals
# into another population, and repeat the process.
# Essentially, this provides a means of
# computing the neural connection weights
# to compute an arbitrary function between populations.
#
# Suppose we are representing a sine wave.

# %%
model = nengo.Network(label="NEF summary")
with model:
    input = nengo.Node(lambda t: np.sin(np.pi * t))
    A = nengo.Ensemble(30, dimensions=1, max_rates=Uniform(80, 100))
    nengo.Connection(input, A)
    A_spikes = nengo.Probe(A.neurons)
    A_probe = nengo.Probe(A, synapse=0.01)

# %%
with nengo.Simulator(model) as sim:
    sim.run(2)

plt.figure(figsize=(10, 3.5))
plt.subplot(1, 2, 1)
plt.plot(sim.trange(), sim.data[A_probe])
plt.title("A")
plt.xlabel("Time (s)")
plt.xlim(0, 2)

ax = plt.subplot(1, 2, 2)
rasterplot(sim.trange(), sim.data[A_spikes], ax)
plt.xlim(0, 2)
plt.title("A")
plt.xlabel("Time (s)")
plt.ylabel("Neuron")
hide_input()
# Out:
#         <a id="583389473" href="javascript:toggle_input_583389473()"
#           >Show Input</a>
#
#         <script type="text/javascript">
#         var toggle_input_583389473;
#         (function() {
#             if (typeof jQuery == 'undefined') {
#                 // no jQuery
#                 var link_583389473 = document.getElementById("583389473");
#                 var cell = link_583389473;
#                 while (cell.className.split(' ')[0] != "cell"
#                        && cell.className.split(' ')[0] != "nboutput") {
#                     cell = cell.parentNode;
#                 }
#                 var input_583389473;
#                 if (cell.className.split(' ')[0] == "cell") {
#                     for (var i = 0; i < cell.children.length; i++) {
#                         if (cell.children[i].className.split(' ')[0]
#                             == "input") {
#                             input_583389473 = cell.children[i];
#                         }
#                     }
#                 } else {
#                     input_583389473 = cell.previousElementSibling;
#                 }
#                 input_583389473.style.display = "none"; // hide
#
#                 toggle_input_583389473 = function() {
#                     if (input_583389473.style.display == "none") {
#                         input_583389473.style.display = ""; // show
#                         link_583389473.innerHTML = "Hide Input";
#                     } else {
#                         input_583389473.style.display = "none"; // hide
#                         link_583389473.innerHTML = "Show Input";
#                     }
#                 }
#
#             } else {
#                 // jQuery
#                 var link_583389473 = $("a[id='583389473']");
#                 var cell_583389473 = link_583389473.parents("div.cell:first");
#                 if (cell_583389473.length == 0) {
#                     cell_583389473 = link_583389473.parents(
#                         "div.nboutput:first");
#                 }
#                 var input_583389473 = cell_583389473.children("div.input");
#                 if (input_583389473.length == 0) {
#                     input_583389473 = cell_583389473.prev("div.nbinput");
#                 }
#                 input_583389473.hide();
#
#                 toggle_input_583389473 = function() {
#                     if (input_583389473.is(':hidden')) {
#                         input_583389473.slideDown();
#                         link_583389473[0].innerHTML = "Hide Input";
#                     } else {
#                         input_583389473.slideUp();
#                         link_583389473[0].innerHTML = "Show Input";
#                     }
#                 }
#             }
#         }());
#         </script>

# %% [markdown]
# Linear transformations of that signal
# involve solving for the usual decoders,
# and scaling those decoding weights.
# Let us flip this sine wave upside down
# as it is transmitted between two populations
# (i.e. population A and population -A).

# %%
with model:
    minusA = nengo.Ensemble(30, dimensions=1, max_rates=Uniform(80, 100))
    nengo.Connection(A, minusA, function=lambda x: -x)
    minusA_spikes = nengo.Probe(minusA.neurons)
    minusA_probe = nengo.Probe(minusA, synapse=0.01)

# %%
with nengo.Simulator(model) as sim:
    sim.run(2)

plt.figure(figsize=(10, 5))
plt.subplot(2, 2, 1)
plt.plot(sim.trange(), sim.data[A_probe])
plt.title("A")
plt.xticks(())
plt.xlim(0, 2)

plt.subplot(2, 2, 3)
plt.plot(sim.trange(), sim.data[minusA_probe])
plt.title("-A")
plt.xlabel("Time (s)")
plt.xlim(0, 2)

ax = plt.subplot(2, 2, 2)
rasterplot(sim.trange(), sim.data[A_spikes], ax)
plt.xlim(0, 2)
plt.title("A")
plt.xticks(())
plt.ylabel("Neuron")

ax = plt.subplot(2, 2, 4)
rasterplot(sim.trange(), sim.data[minusA_spikes], ax)
plt.xlim(0, 2)
plt.title("-A")
plt.xlabel("Time (s)")
plt.ylabel("Neuron")
hide_input()
# Out:
#         <a id="964510478" href="javascript:toggle_input_964510478()"
#           >Show Input</a>
#
#         <script type="text/javascript">
#         var toggle_input_964510478;
#         (function() {
#             if (typeof jQuery == 'undefined') {
#                 // no jQuery
#                 var link_964510478 = document.getElementById("964510478");
#                 var cell = link_964510478;
#                 while (cell.className.split(' ')[0] != "cell"
#                        && cell.className.split(' ')[0] != "nboutput") {
#                     cell = cell.parentNode;
#                 }
#                 var input_964510478;
#                 if (cell.className.split(' ')[0] == "cell") {
#                     for (var i = 0; i < cell.children.length; i++) {
#                         if (cell.children[i].className.split(' ')[0]
#                             == "input") {
#                             input_964510478 = cell.children[i];
#                         }
#                     }
#                 } else {
#                     input_964510478 = cell.previousElementSibling;
#                 }
#                 input_964510478.style.display = "none"; // hide
#
#                 toggle_input_964510478 = function() {
#                     if (input_964510478.style.display == "none") {
#                         input_964510478.style.display = ""; // show
#                         link_964510478.innerHTML = "Hide Input";
#                     } else {
#                         input_964510478.style.display = "none"; // hide
#                         link_964510478.innerHTML = "Show Input";
#                     }
#                 }
#
#             } else {
#                 // jQuery
#                 var link_964510478 = $("a[id='964510478']");
#                 var cell_964510478 = link_964510478.parents("div.cell:first");
#                 if (cell_964510478.length == 0) {
#                     cell_964510478 = link_964510478.parents(
#                         "div.nboutput:first");
#                 }
#                 var input_964510478 = cell_964510478.children("div.input");
#                 if (input_964510478.length == 0) {
#                     input_964510478 = cell_964510478.prev("div.nbinput");
#                 }
#                 input_964510478.hide();
#
#                 toggle_input_964510478 = function() {
#                     if (input_964510478.is(':hidden')) {
#                         input_964510478.slideDown();
#                         link_964510478[0].innerHTML = "Hide Input";
#                     } else {
#                         input_964510478.slideUp();
#                         link_964510478[0].innerHTML = "Show Input";
#                     }
#                 }
#             }
#         }());
#         </script>

# %% [markdown]
# Nonlinear transformations involve
# solving for a new set of decoding weights.
# Let us add a third population connected
# to the second one and use it to compute $(-A)^2$.

# %%
with model:
    A_squared = nengo.Ensemble(30, dimensions=1, max_rates=Uniform(80, 100))
    nengo.Connection(minusA, A_squared, function=lambda x: x ** 2)
    A_squared_spikes = nengo.Probe(A_squared.neurons)
    A_squared_probe = nengo.Probe(A_squared, synapse=0.02)

# %%
with nengo.Simulator(model) as sim:
    sim.run(2)

plt.figure(figsize=(10, 6.5))
plt.subplot(3, 2, 1)
plt.plot(sim.trange(), sim.data[A_probe])
plt.axhline(0, color="k")
plt.title("A")
plt.xticks(())
plt.xlim(0, 2)

plt.subplot(3, 2, 3)
plt.plot(sim.trange(), sim.data[minusA_probe])
plt.axhline(0, color="k")
plt.title("-A")
plt.xticks(())
plt.xlim(0, 2)

plt.subplot(3, 2, 5)
plt.plot(sim.trange(), sim.data[A_squared_probe])
plt.axhline(0, color="k")
plt.title("(-A)^2")
plt.xlabel("Time (s)")
plt.xlim(0, 2)

ax = plt.subplot(3, 2, 2)
rasterplot(sim.trange(), sim.data[A_spikes], ax)
plt.xlim(0, 2)
plt.title("A")
plt.xticks(())
plt.ylabel("Neuron")

ax = plt.subplot(3, 2, 4)
rasterplot(sim.trange(), sim.data[minusA_spikes], ax)
plt.xlim(0, 2)
plt.title("-A")
plt.xticks(())
plt.ylabel("Neuron")

ax = plt.subplot(3, 2, 6)
rasterplot(sim.trange(), sim.data[A_squared_spikes], ax)
plt.xlim(0, 2)
plt.title("(-A)^2")
plt.xlabel("Time (s)")
plt.ylabel("Neuron")
hide_input()
# Out:
#         <a id="1881965471" href="javascript:toggle_input_1881965471()"
#           >Show Input</a>
#
#         <script type="text/javascript">
#         var toggle_input_1881965471;
#         (function() {
#             if (typeof jQuery == 'undefined') {
#                 // no jQuery
#                 var link_1881965471 = document.getElementById("1881965471");
#                 var cell = link_1881965471;
#                 while (cell.className.split(' ')[0] != "cell"
#                        && cell.className.split(' ')[0] != "nboutput") {
#                     cell = cell.parentNode;
#                 }
#                 var input_1881965471;
#                 if (cell.className.split(' ')[0] == "cell") {
#                     for (var i = 0; i < cell.children.length; i++) {
#                         if (cell.children[i].className.split(' ')[0]
#                             == "input") {
#                             input_1881965471 = cell.children[i];
#                         }
#                     }
#                 } else {
#                     input_1881965471 = cell.previousElementSibling;
#                 }
#                 input_1881965471.style.display = "none"; // hide
#
#                 toggle_input_1881965471 = function() {
#                     if (input_1881965471.style.display == "none") {
#                         input_1881965471.style.display = ""; // show
#                         link_1881965471.innerHTML = "Hide Input";
#                     } else {
#                         input_1881965471.style.display = "none"; // hide
#                         link_1881965471.innerHTML = "Show Input";
#                     }
#                 }
#
#             } else {
#                 // jQuery
#                 var link_1881965471 = $("a[id='1881965471']");
#                 var cell_1881965471 = link_1881965471.parents("div.cell:first");
#                 if (cell_1881965471.length == 0) {
#                     cell_1881965471 = link_1881965471.parents(
#                         "div.nboutput:first");
#                 }
#                 var input_1881965471 = cell_1881965471.children("div.input");
#                 if (input_1881965471.length == 0) {
#                     input_1881965471 = cell_1881965471.prev("div.nbinput");
#                 }
#                 input_1881965471.hide();
#
#                 toggle_input_1881965471 = function() {
#                     if (input_1881965471.is(':hidden')) {
#                         input_1881965471.slideDown();
#                         link_1881965471[0].innerHTML = "Hide Input";
#                     } else {
#                         input_1881965471.slideUp();
#                         link_1881965471[0].innerHTML = "Show Input";
#                     }
#                 }
#             }
#         }());
#         </script>

# %% [markdown]
# ## Principle 3: Dynamics
#
# So far, we have been considering the values
# represented by ensembles as generic "signals."
# However, if we think of them instead
# as state variables in a dynamical system,
# then we can apply the methods of control theory
# or dynamic systems theory to brain models.
# Nengo automatically translates from standard dynamical systems descriptions
# to descriptions consistent with neural dynamics.
#
# In order to get interesting dynamics,
# we can connect populations recurrently (i.e., to themselves).
#
# Below is a simple harmonic oscillator
# implemented using this third principle.
# It needs is a bit of input to get it started.

# %%
model = nengo.Network(label="NEF summary")
with model:
    input = nengo.Node(lambda t: [1, 0] if t < 0.1 else [0, 0])
    oscillator = nengo.Ensemble(200, dimensions=2)
    nengo.Connection(input, oscillator)
    nengo.Connection(oscillator, oscillator, transform=[[1, 1], [-1, 1]], synapse=0.1)
    oscillator_probe = nengo.Probe(oscillator, synapse=0.02)

# %%
with nengo.Simulator(model) as sim:
    sim.run(3)

plt.figure(figsize=(10, 3.5))
plt.subplot(1, 2, 1)
plt.plot(sim.trange(), sim.data[oscillator_probe])
plt.ylim(-1.2, 1.2)
plt.xlabel("Time (s)")

plt.subplot(1, 2, 2)
plt.plot(sim.data[oscillator_probe][:, 0], sim.data[oscillator_probe][:, 1])
plt.grid()
plt.axis([-1.2, 1.2, -1.2, 1.2])
plt.xlabel("$x_1$")
plt.ylabel("$x_2$")
hide_input()
# Out:
#         <a id="1630863430" href="javascript:toggle_input_1630863430()"
#           >Show Input</a>
#
#         <script type="text/javascript">
#         var toggle_input_1630863430;
#         (function() {
#             if (typeof jQuery == 'undefined') {
#                 // no jQuery
#                 var link_1630863430 = document.getElementById("1630863430");
#                 var cell = link_1630863430;
#                 while (cell.className.split(' ')[0] != "cell"
#                        && cell.className.split(' ')[0] != "nboutput") {
#                     cell = cell.parentNode;
#                 }
#                 var input_1630863430;
#                 if (cell.className.split(' ')[0] == "cell") {
#                     for (var i = 0; i < cell.children.length; i++) {
#                         if (cell.children[i].className.split(' ')[0]
#                             == "input") {
#                             input_1630863430 = cell.children[i];
#                         }
#                     }
#                 } else {
#                     input_1630863430 = cell.previousElementSibling;
#                 }
#                 input_1630863430.style.display = "none"; // hide
#
#                 toggle_input_1630863430 = function() {
#                     if (input_1630863430.style.display == "none") {
#                         input_1630863430.style.display = ""; // show
#                         link_1630863430.innerHTML = "Hide Input";
#                     } else {
#                         input_1630863430.style.display = "none"; // hide
#                         link_1630863430.innerHTML = "Show Input";
#                     }
#                 }
#
#             } else {
#                 // jQuery
#                 var link_1630863430 = $("a[id='1630863430']");
#                 var cell_1630863430 = link_1630863430.parents("div.cell:first");
#                 if (cell_1630863430.length == 0) {
#                     cell_1630863430 = link_1630863430.parents(
#                         "div.nboutput:first");
#                 }
#                 var input_1630863430 = cell_1630863430.children("div.input");
#                 if (input_1630863430.length == 0) {
#                     input_1630863430 = cell_1630863430.prev("div.nbinput");
#                 }
#                 input_1630863430.hide();
#
#                 toggle_input_1630863430 = function() {
#                     if (input_1630863430.is(':hidden')) {
#                         input_1630863430.slideDown();
#                         link_1630863430[0].innerHTML = "Hide Input";
#                     } else {
#                         input_1630863430.slideUp();
#                         link_1630863430[0].innerHTML = "Show Input";
#                     }
#                 }
#             }
#         }());
#         </script>
